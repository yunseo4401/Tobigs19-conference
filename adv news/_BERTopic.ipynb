# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

ad=pd.read_csv('/content/drive/MyDrive/news_final.csv')

# %%
ad
# Out:
#        Unnamed: 0   매체명                                     광고주  \
# 0             158  서울경제                              현대자동차 외 3사
# 1             160  서울경제                              피타소프트 외 4사
# 2             161  서울경제                             현대종합상조 외 4사
# 3             163  서울경제                               아이소이 외 3사
# 4             206  서울경제                            현대엠엔소프트 외 3사
# ...           ...   ...                                     ...
# 16037       50206  중앙일보                                    LG전자
# 16038       50207  중앙일보                                   SSG닷컴
# 16039       50209  중앙일보                               한국산업기술대학교
# 16040       50210  중앙일보  광동(1833-2625)/\n피디엔에이(070-4870-\n0708)
# 16041       50211  중앙일보  광동(1833-2625)/\n피디엔에이(070-4870-\n0708)
#
#                            상품명                                        link1  \
# 0                   쏘나타 하이브리드외  https://www.sedaily.com/NewsView/1HVD95BPV5
# ...

# %%
ad=ad.drop('Unnamed: 0',axis=1)
ad=ad.drop('광고주',axis=1)
ad=ad.drop('상품명',axis=1)
ad=ad.drop('link1',axis=1)

# %%
text_len=[]
for text in ad.text1:
  length=len(text.split())
  text_len.append(length)

# %%
ad['text_len']=text_len

# %%
ad[ad['text_len']<10] #길이 10 미만 제거하기
# Out:
#         매체명                                              text1  text_len
# 2369   조선일보                         사회기사입력 2022-11-16 10:20:16         3
# 2393   조선일보                         생활기사입력 2022-04-19 08:53:12         3
# 2426   조선일보                         생활기사입력 2012-12-03 09:12:13         3
# 2431   조선일보                         경제기사입력 2023-02-23 16:11:41         3
# 2437   조선일보                         생활기사입력 2013-08-08 08:58:22         3
# ...     ...                                                ...       ...
# 12434  조선일보                         경제기사입력 2020-10-04 16:05:27         3
# 12462  중앙일보  피로회복제라고 효과가 모두 같을까요?\n아로나민은 '활성비타민효과'로 말합니다\nA...         8
# 12623  중앙일보    원적외선 힐링!\n고객 감사행사 (1월 4일까지 한시적임)\nADVERTISEMENT         8
# 12660  중앙일보    원적외선 힐링!\n고객 감사행사 (1월 4일까지 한시적임)\nADVERTISEMENT         8
# 14266  중앙일보  ◆동양생명 <임원 승진> ▶전무(영업부문총괄) 김태현(영업부문부총괄) ▶상무(경영전...         8
#
# [191 rows x 3 columns]

# %%
ad=ad[ad['text_len']>10]

# %%
ad.sort_values(by=['text_len'],ascending=False)
# Out:
#           매체명                                              text1  text_len
# 5863     한국경제  이번 주(11월5일~11월11일) 전국 7대 도시에서 새로 설립된 기업 수는 137...      4819
# 6339     한국경제  이번 주(11월5일~11월11일) 전국 7대 도시에서 새로 설립된 기업 수는 137...      4819
# 8505   파이낸셜뉴스  2018년 한반도는 그 어느 때보다 숨가쁜 변화를 경험하고 있다. 지난해 북한과 미...      3940
# 10093    한국경제  이번 주(5월21일~5월27일) 전국 7대 도시에서 새로 설립된 기업 수는 1177...      3825
# 9019     한국경제  이번 주(5월28일~6월3일) 전국 7대 도시에서 새로 설립된 기업 수는 1093개...      3729
# ...       ...                                                ...       ...
# 12624    중앙일보  어설픈 맛집은 가라!\n언론과 방송도 인정한 진짜 맛집, 리틀족발이!\n리틀족발이 ...        13
# 12868    중앙일보  어설픈 맛집은 가라!\n언론과 방송도 인정한 진짜 맛집, 리틀족발이!\n리틀족발이 ...        13
# 12485    중앙일보  NX300 출시기념 Brand New 페스티벌\nNX300 출시기념 사은혜택을 만나...        12
# 10292    조선일보  경제기사입력 2017-07-17 09:39:05마감직전토토 국내 유일 실시간 현장정...        11
# 4635     조선일보  어수봉(64) 전 한국기술교육대학교 교수가 2일 한국산업인력공단 제15대 이사장에 ...        11
#
# [15851 rows x 3 columns]

# %%
#중복제거
ad=ad.drop_duplicates(subset='text1')

# %%
ad.reset_index(drop=True,inplace=True)

# %%
ad
# Out:
#         매체명                                              text1  text_len
# 0      서울경제  현대차의 쏘나타 하이브리드가 출시되자 가솔린 쏘나타를 계약했던 소비자들의 28%가 ...       494
# 1      서울경제  지난해 고객들의 입소문을 타고 풀HD 블랙박스 시장에서 두각을 나타낸 피타소프트가 ...       198
# 2      서울경제  현대종합상조는 실속형 프리미엄 상품인 '피르드 스마트'를 최근 고객들에게 적극 추천...       234
# 3      서울경제  천연 기능성 화장품 브랜드 아이소이는 베스트셀러 '불가리안 로즈 블레미쉬 케어세럼(...       220
# 4      서울경제  현대엠엔소프트는 14일 기상청과 KBS가 공동으로 참여한 웨비게이션(Weavigat...        69
# ...     ...                                                ...       ...
# 12360  중앙일보  숙박과 스페인 요리를 즐길 수 있는 쁘띠프랑스의 ‘유럽생활여행’.\n가을 나들이와 ...       137
# 12361  중앙일보  선종구 전 하이마트 회장. [중앙포토]\n대법원이 선종구 전 롯데하이마트 회장을 하...       265
# 12362  중앙일보  LG전자의 퓨리케어 360° 공기청정기가 국가공인시험검사기관인 한국건설생활환경시험연...       151
# 12363  중앙일보  신세계그룹의 온라인 쇼핑 플랫폼인 SSG닷컴(쓱닷컴)이 ESG(친환경·사회적 책임·...       505
# 12364  중앙일보  한국산업기술대학교(총장 박건수)가 2022년 3월 1일부로 한국공학대학교로 교명을 ...       134
#
# [12365 rows x 3 columns]

# %% [markdown]
# #문서 요약 필요

# %%
# !pip install textrankr

# %%
# !pip install konlpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 36.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.3/465.3 kB 43.6 MB/s eta 0:00:00
# ...

# %%
from typing import List
from konlpy.tag import Okt

class OktTokenizer:
    okt: Okt = Okt()

    def __call__(self, text: str) -> List[str]:
        tokens: List[str] = self.okt.phrases(text)
        return tokens

# %%
from typing import List
from textrankr import TextRank

mytokenizer: OktTokenizer = OktTokenizer()
textrank: TextRank = TextRank(mytokenizer)

k: int = 3  # num sentences in the resulting summary
summaries: List[str] = []

for index, row in ad.iterrows():
    text = row['text1']
    # text를 요약
    summary = textrank.summarize(text, k)
    summaries.append(summary)

# 요약 결과를 'summary' 칼럼에 담기
ad['summary'] = summaries

# %%
ad.reset_index(drop=True,inplace=True)

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.tag import pos_tag
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
def remove_proper_nouns(text):
    # 문장 단위로 텍스트를 분리
    sentences = sent_tokenize(text)
    result = []

    for sentence in sentences:
        # 단어 토큰화 및 품사 태깅
        words = word_tokenize(sentence)
        tagged_words = pos_tag(words)

        # 품사 태그가 'NNP' (고유명사)가 아닌 단어들만 결과에 추가
        non_proper_nouns = [word for word, tag in tagged_words if tag != 'NNP']
        result.extend(non_proper_nouns)

    # 결과를 다시 문장으로 결합하여 반환
    return ' '.join(result)

# %%
ad['summary_1']=ad['summary'].apply(remove_proper_nouns)

# %%
import re
ad.summary=ad.summary.apply(lambda x: re.sub('[^A-Za-z0-9가-힣]',' ',x))
ad.summary=ad.summary.apply(lambda x: re.sub(' +',' ',x))
ad.summary = ad.summary.apply(lambda x: re.sub('\n','',x))
ad.summary = ad.summary.apply(lambda x:re.sub('\u200b','',x))
ad.summary = ad.summary.apply(lambda x:re.sub('\xa0','',x))
ad.summary = ad.summary.apply(lambda x:re.sub('([a-zA-Z])','',x))
ad.summary = ad.summary.apply(lambda x:re.sub('[ㄱ-ㅎㅏ-ㅣ]+','',x))
ad.summary = ad.summary.apply(lambda x:re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]','',x))

# %%
# !wget https://raw.githubusercontent.com/byungjooyoo/Dataset/main/korean_stopwords.txt
with open('korean_stopwords.txt', 'r') as f:
    stop_words = f.read().split("\n")
print(len(stop_words), stop_words[:10])
# Out:
# --2023-10-26 04:38:01--  https://raw.githubusercontent.com/byungjooyoo/Dataset/main/korean_stopwords.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7007 (6.8K) [text/plain]
# Saving to: ‘korean_stopwords.txt’
#
# korean_stopwords.tx 100%[===================>]   6.84K  --.-KB/s    in 0s
#
# 2023-10-26 04:38:01 (103 MB/s) - ‘korean_stopwords.txt’ saved [7007/7007]
#
# 675 ['아', '휴', '아이구', '아이쿠', '아이고', '어', '나', '우리', '저희', '따라']

# %%
new_word = ['기자','뉴스','했다','무단','재배포','금지','사진제공','저작권자','및','전재','서울경제']

for i in range(len(new_word)):
  stop_words.append(new_word[i])

# %%
value_to_remove = '금','뿐이다','의거하여','근거하여','입각하여','기준으로','하는 편이 낫다','오르다','반드시','해야한다','할줄알다','할수있다','할수있어','임에 틀림없다','겨우','단지','훨씬','얼만큼','얼마만큼','더욱더','당장',''

while value_to_remove in stop_words:
  stop_words.remove(value_to_remove)

# %%
# !pip install nltk

# %%
def remove_stopwords(text,stop_words):
    stop_words = stop_words  # 해당 언어에 맞는 불용어 세트를 선택합니다.
    tokens = word_tokenize(text)  # 텍스트를 토큰화합니다.
    filtered_tokens = [token for token in tokens if token.lower() not in stop_words]  # 불용어가 아닌 토큰만 선택합니다.
    filtered_text = ' '.join(filtered_tokens)  # 처리된 토큰들을 다시 문장으로 변환합니다.
    return filtered_text

# %%
from nltk.tokenize import word_tokenize
ad['summary_clean'] = ad['summary'].apply(lambda x: remove_stopwords(x, stop_words))

# %%
ad.reset_index(drop=True,inplace=True)

# %%
# !python -m spacy download ko_core_news_lg
# Out:
# 2023-10-26 04:39:58.457761: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-26 04:39:58.457826: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-26 04:39:58.457860: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-26 04:39:58.466181: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
import spacy

# %%
nlp=spacy.load('ko_core_news_lg')

# %%
def tokenizer(text):
  doc=nlp(text)
  lemmas=[]
  texts_list=[token.lemma_.split('+') for token in doc]
  tags_list=[token.tag_.split('+') for token in doc]
  for token_idx in range(len(doc)):
    if tags_list[token_idx][0] in ('ncn','ncpa','ncps','nc','nq','f','pvg','paa'):
      if len(texts_list[token_idx])==len(tags_list[token_idx]):
        if tags_list[token_idx][0].startswith('n') or tags_list[token_idx][0].startswith('f'):
          lemmas.append(''.join([text for tag,text in zip(tags_list[token_idx],texts_list[token_idx]) if tag in ('ncn','ncpa','ncps','nc','nq','f')]))
        else:
          lemmas.append(texts_list[token_idx][0]+'다')
      elif tags_list[token_idx][0] in ('ncn','ncpa','ncps','nc','f'):
        lemmas.append(texts_list[token_idx][0])
      else:
        lemmas.append(''.join((texts_list[token_idx])).replace(' ','_'))
  return lemmas

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer=TfidfVectorizer(tokenizer=tokenizer,ngram_range=(1,1),stop_words=stop_words, max_df=0.95, min_df=1)

# %%
ad['summary_clean'][10]
# Out:
# '홈플러스 온라인이 익스프레스 기반 즉시배송 20대 고객 비중과 50대 고객 매출이 크게 증가했다고 19일 밝혔다 홈플러스 익스프레스 운영하는 즉시배송 은 주문 시 1시간 내외로 배송 받을 수 있는 퀵커머스 서비스다 즉시배송 서비스는 지난해 8월부터 시작한 3만원 무료배송 정책 이후로 매월 기준 3 4만원대 주문 비중이 70 이상을 차지한다'

# %%
vectorizer.fit(ad.summary_clean)
vectorizer.vocabulary_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# ...

# %%
# !pip install hdbscan
# !pip uninstall umap-learn
# !pip install umap-learn
# !pip install bertopic[visualization]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 44.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached Cython-0.29.36-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# ...
#   Created wheel for hdbscan: filename=hdbscan-0.8.33-cp310-cp310-linux_x86_64.whl size=3039169 sha256=860ea5c52b45c71f8fea3d0bfeda49b3a2cc8c96b027f89b232b2ca002b65481
#   Stored in directory: /root/.cache/pip/wheels/75/0b/3b/dc4f60b7cc455efaefb62883a7483e76f09d06ca81cf87d610
# Successfully built hdbscan
# ...
#   Attempting uninstall: cython
#     Found existing installation: Cython 3.0.4
#     Uninstalling Cython-3.0.4:
#       Successfully uninstalled Cython-3.0.4
# ...
# WARNING: Skipping umap-learn as it is not installed.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.8/90.8 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
import umap
import hdbscan
umap_model=umap.UMAP(n_neighbors=15,min_dist=0.1,n_components=5,random_state=42,metric='cosine')
hdbscan_model=hdbscan.HDBSCAN(min_cluster_size=10,metric='euclidean',cluster_selection_method='eom',prediction_data=True)

# %%
# !pip install bertopic

# %%
from bertopic import BERTopic
model=BERTopic(embedding_model="sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens",\
               vectorizer_model=vectorizer,
               top_n_words=15,
               min_topic_size=10,
               umap_model=umap_model,hdbscan_model=hdbscan_model,
               verbose=True)

# %%
ad
# Out:
#         매체명                                              text1  text_len  \
# 0      서울경제  현대차의 쏘나타 하이브리드가 출시되자 가솔린 쏘나타를 계약했던 소비자들의 28%가 ...       494
# 1      서울경제  지난해 고객들의 입소문을 타고 풀HD 블랙박스 시장에서 두각을 나타낸 피타소프트가 ...       198
# 2      서울경제  현대종합상조는 실속형 프리미엄 상품인 '피르드 스마트'를 최근 고객들에게 적극 추천...       234
# 3      서울경제  천연 기능성 화장품 브랜드 아이소이는 베스트셀러 '불가리안 로즈 블레미쉬 케어세럼(...       220
# 4      서울경제  현대엠엔소프트는 14일 기상청과 KBS가 공동으로 참여한 웨비게이션(Weavigat...        69
# ...     ...                                                ...       ...
# 12360  중앙일보  숙박과 스페인 요리를 즐길 수 있는 쁘띠프랑스의 ‘유럽생활여행’.\n가을 나들이와 ...       137
# 12361  중앙일보  선종구 전 하이마트 회장. [중앙포토]\n대법원이 선종구 전 롯데하이마트 회장을 하...       265
# 12362  중앙일보  LG전자의 퓨리케어 360° 공기청정기가 국가공인시험검사기관인 한국건설생활환경시험연...       151
# 12363  중앙일보  신세계그룹의 온라인 쇼핑 플랫폼인 SSG닷컴(쓱닷컴)이 ESG(친환경·사회적 책임·...       505
# 12364  중앙일보  한국산업기술대학교(총장 박건수)가 2022년 3월 1일부로 한국공학대학교로 교명을 ...       134
#
#                                                  summary  \
# ...

# %%
nlp.max_length = 2000000000

# %%
short=ad[0:7000]

# %%
topics,probs=model.fit_transform(ad.summary_clean)
# Out:
# ...
# Batches:   0%|          | 0/387 [00:00<?, ?it/s]
# 2023-10-26 04:49:03,049 - BERTopic - Transformed documents to Embeddings
# 2023-10-26 04:49:45,426 - BERTopic - Reduced dimensionality
# 2023-10-26 04:49:46,135 - BERTopic - Clustered reduced embeddings

# %%
model.get_topic_info()
# Out:
#     Topic  Count                    Name  \
# 0      -1   5775         -1_제품_출시_투자_서비스
# 1       0   3028     0_분양_아파트_힐스테이트_오피스텔
# 2       1    341           1_맛_메뉴_오뚜기_요리
# 3       2    313           2_환자_수술_치료_병원
# 4       3    184     3_비타민_단백질_벤포티아민_고함량
# ..    ...    ...                     ...
# 68     67     11    67_공기청정기_에어컨_퓨리케어_실내
# 69     68     11         68_북상_태풍_상륙_힌남노
# 70     69     11       69_보험_운전자_운전자보험_맵
# 71     70     10       70_헤지펀드_잔고_월세_일임형
# 72     71     10  71_엘루비_메노락토_치센캡슐_에스트로겐
#
#                                        Representation  \
# 0   [제품, 출시, 투자, 서비스, 브랜드, 펀드, 분양, 상품, 시장, 국내, 위하다...
# 1   [분양, 아파트, 힐스테이트, 오피스텔, 서울, 지상, 조감, 전용면, 편한세상, ...
# 2   [맛, 메뉴, 오뚜기, 요리, 농심, 피자, 맛있다, 치킨, 넣다, 소스, 먹다, ...
# 3   [환자, 수술, 치료, 병원, 원장, 진료, 암, 통증, 척추, 의료진, 백내장, ...
# 4   [비타민, 단백질, 벤포티아민, 고함량, 비맥스, 섭취, 체내, 함유, 아연, 활성...
# ..                                                ...
# 68  [공기청정기, 에어컨, 퓨리케어, 실내, 연동, 알파, 공기질, 에어가드폰, 탈취,...
# ...

# %%
model.get_topic(0)
# Out:
# [('분양', 0.026972809969343953),
#  ('아파트', 0.015615321021312295),
#  ('힐스테이트', 0.014377152603983954),
#  ('오피스텔', 0.014282410412280552),
#  ('서울', 0.013665320056589462),
#  ('지상', 0.01313505666034713),
#  ('조감', 0.01242577897594356),
#  ('전용면', 0.01105054808853218),
#  ('편한세상', 0.010658158560298413),
#  ('경기도', 0.010635362450729385),
#  ('지하', 0.010176320996803708),
#  ('상가', 0.009456406695964863),
#  ('푸르지오', 0.009211177161469292),
#  ('조성', 0.009199754422323984),
#  ('인천', 0.009146289156150912)]

# %%
model.get_topic(1)
# Out:
# [('맛', 0.02558558390393056),
#  ('메뉴', 0.01859218479690513),
#  ('오뚜기', 0.018314169692928414),
#  ('요리', 0.01724860164274821),
#  ('농심', 0.01481194227122557),
#  ('피자', 0.014524994443224786),
#  ('맛있다', 0.014160022052630054),
#  ('치킨', 0.014137392667061913),
#  ('넣다', 0.01358770403626221),
#  ('소스', 0.013522131442832201),
#  ('먹다', 0.012758945233388393),
#  ('바나나', 0.011732877490335044),
#  ('피노누아', 0.01143360384911999),
#  ('과일', 0.011136991233211383),
#  ('국물', 0.011021959943213384)]

# %%
model.get_topic(2)
# Out:
# [('환자', 0.05635560823021926),
#  ('수술', 0.055553439399844064),
#  ('치료', 0.04895414091319147),
#  ('병원', 0.03760296739498027),
#  ('원장', 0.031088847301337406),
#  ('진료', 0.026495136695637793),
#  ('암', 0.02591613871923654),
#  ('통증', 0.022456480222177513),
#  ('척추', 0.02007114045929247),
#  ('의료진', 0.019966847894888413),
#  ('백내장', 0.01832197733521642),
#  ('비수술', 0.01832086994494052),
#  ('의료', 0.017709232425685475),
#  ('관절', 0.013869102158510612),
#  ('척추관협착증', 0.013303530262623256)]
