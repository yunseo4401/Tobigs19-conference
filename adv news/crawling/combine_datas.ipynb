# %%
import pandas as pd

# %%
# 크롤링한 데이터 통합
tmp = pd.read_csv('result1_sedaily.csv', index_col=0)
tmp2 = pd.read_csv('result2_sedaily.csv', index_col=0)
tmp3 = pd.read_csv('result3_sedaily.csv', index_col=0)
tmp4 = pd.read_csv('result4_sedaily.csv', index_col=0)
tmp5 = pd.read_csv('result5_sedaily.csv', index_col=0)
tmp6 = pd.read_csv('result6_sedaily.csv', index_col=0)

tmp7 = pd.read_csv('result4_asiae.csv', index_col=0)
tmp8 = pd.read_csv('result3_isplus.csv', index_col=0)

tmp9 = pd.read_csv('result_ajunews1.csv', index_col=0)
tmp10 = pd.read_csv('result_ajunews2.csv', index_col=0)
tmp11 = pd.read_csv('result_ajunews3.csv', index_col=0)
tmp12 = pd.read_csv('result_ajunews4.csv', index_col=0)
tmp13 = pd.read_csv('result_ajunews5.csv', index_col=0)
tmp14 = pd.read_csv('result_ajunews6.csv', index_col=0)
tmp15 = pd.read_csv('result_chosun.csv', index_col=0)
tmp16 = pd.read_csv('result_hankyung.csv', index_col=0)

tmp17 = pd.read_csv('result_fnnews1.csv', index_col=0)
tmp18 = pd.read_csv('result_fnnews2.csv', index_col=0)
tmp19 = pd.read_csv('result_hankyung2.csv', index_col=0)
tmp20 = pd.read_csv('result_chosun2.csv', index_col=0)


tmp21 = pd.read_csv('result_joongang1.csv', index_col=0)
tmp22 = pd.read_csv('result_joongang2.csv', index_col=0)

result = pd.concat([tmp, tmp2, tmp3, tmp4, tmp5, tmp6, tmp7, tmp8, tmp9, tmp10, tmp11, tmp12, tmp13, tmp14, tmp15, tmp16, tmp17, tmp18, tmp19, tmp20, tmp21, tmp22])
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21492 entries, 158 to 50211
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   매체명     21492 non-null  object
#  1   게재일     21492 non-null  object
#  2   광고주     21473 non-null  object
#  3   연도      21492 non-null  int64
#  4   상품명     21492 non-null  object
#  5   site    21492 non-null  object
#  6   쿼리      21492 non-null  object
#  7   link1   21492 non-null  object
#  8   link2   21492 non-null  object
#  9   link3   21492 non-null  object
#  10  title1  1496 non-null   object
#  11  title2  1335 non-null   object
#  12  title3  1284 non-null   object
#  13  text1   16944 non-null  object
#  14  text2   1335 non-null   object
#  15  text3   1284 non-null   object
#  16  date    1280 non-null   object
#  17  date1   201 non-null    object
#  18  date2   3 non-null      object
#  19  date3   4 non-null      object
# dtypes: int64(1), object(19)
# ...

# %%
# NA포함 행 제거, 중복 행 제거
result2 = result.drop(columns=['게재일', '연도', 'site', '쿼리', 'date', 'date1', 'date2', 'date3', 'link2', 'link3', 'title1', 'title2', 'title3', 'text2', 'text3']).dropna(subset=['text1']).drop_duplicates()
result2
# Out:
#         매체명                                     광고주                      상품명  \
# 158    서울경제                              현대자동차 외 3사               쏘나타 하이브리드외
# 160    서울경제                              피타소프트 외 4사     블랙뷰 와이파이DR500GW-HD 외
# 161    서울경제                             현대종합상조 외 4사                프리드 스마트 외
# 163    서울경제                               아이소이 외 3사      블가리안 로즈 블레미쉬 케어세럼 외
# 206    서울경제                            현대엠엔소프트 외 3사          소프트맨 내비게이션 외 3건
# ...     ...                                     ...                      ...
# 50206  중앙일보                                    LG전자        퓨리케어 360도 공기청정기 펫
# 50207  중앙일보                                   SSG닷컴                    SSG닷컴
# 50209  중앙일보                               한국산업기술대학교                한국산업기술대학교
# 50210  중앙일보  광동(1833-2625)/\n피디엔에이(070-4870-\n0708)                    광동진녹경
# 50211  중앙일보  광동(1833-2625)/\n피디엔에이(070-4870-\n0708)  피디엔 에이 오리지널 제품고객 감사 이벤트
#
# ...

# %%
# csv파일 저장
result2.to_csv('news_16042rows.csv')
